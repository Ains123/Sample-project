# %% [markdown]
# # Student Performance & Study Habits Analysis (Python + SQL)
#
# ## Step 1: Load the dataset

# %%
import pandas as pd

df = pd.read_csv("../data/raw/student_performance_120.csv")

df.head()
# Out:
#    student_id  study_time_hours  sleep_hours  attendance_rate  final_grade
# 0           1                 4            5               91           98
# 1           2                 5            7               68           91
# 2           3                 3            8              100           55
# 3           4                 5            6               94           64
# 4           5                 5            4               78           92

# %% [markdown]
# ## Step 2: Inspect Dataset

# %%
print("Shape:", df.shape)
print(df.info())

# %% [markdown]
# ## Step 3: Check Missing Values

# %%
df.isna().sum()

# %% [markdown]
# ## Step 4: Check Duplicate Rows

# %%
df.duplicated().sum()

# %% [markdown]
# ## Step 5: Clean Column Names

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df.columns

# %% [markdown]
# ## Step 6: Handle Missing Values (Simple)

# %%
df = df.fillna("Unknown")
